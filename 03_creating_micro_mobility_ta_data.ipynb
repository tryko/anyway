# %% [markdown]
# # Create Data for Tel Aviv with just Micro Mobility

# %%
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
import pandas as pd
import numpy as np
from IPython.display import Image, display

# %%
BICYCLE = 15
SCOOTER = 21
E_BICYCLE = 23

micro_m = [SCOOTER, E_BICYCLE, BICYCLE]

# %% [markdown]
# ## Loading Tel Aviv Data

# %%
i_m_h_ta_gdf = gpd.read_parquet('./csv_tables/i_m_h_ta_gdf.parquet')
i_m_h_ta_gdf.head()
# Out:
#    accident_id  provider_and_id  provider_code  file_type_police  \
# 0   2013001076      32013001076              3                 3
# 1   2013001885      32013001885              3                 3
# 2   2013000001      12013000001              1                 1
# 3   2013002115      32013002115              3                 3
# 4   2013000005      12013000005              1                 1
#
#    involved_type involved_type_hebrew  license_acquiring_date  age_group  \
# 0              1                  נהג                    2010         13
# 1              2             נהג נפגע                    2003          7
# 2              3                 נפגע                       0         12
# 3              1                  נהג                       0         99
# 4              1                  נהג                    2006         10
#
#   age_group_hebrew  sex  ... vehicle_status_hebrew  vehicle_attribution  \
# 0            60-64    1  ...                  None                  1.0
# 1            30-34    1  ...                  None                  1.0
# 2            55-59    1  ...                  None                  NaN
# 3          לא ידוע    0  ...                  None                  1.0
# 4            45-49    1  ...                  None                  1.0
#
#   vehicle_attribution_hebrew  seats total_weight  total_weight_hebrew  \
# 0                     ישראלי    3.0          1.0               עד 1.9
# 1                     ישראלי    1.0          NaN                 None
# 2                       None    NaN          NaN                 None
# 3                     ישראלי   99.0          0.0              לא ידוע
# 4                     ישראלי   35.0         11.0            16.0-19.0
#
#   vehicle_damage  vehicle_damage_hebrew        accident_date  \
# 0            4.0                אין נזק  2013-09-07 00:30:00
# 1            4.0                אין נזק  2013-11-02 01:45:00
# 2            NaN                   None  2013-01-02 00:00:00
# 3            1.0                     קל  2013-04-16 02:15:00
# 4            4.0                אין נזק  2013-01-09 00:00:00
#
#                 geometry
# 0  POINT (34.782 32.087)
# 1  POINT (34.789 32.096)
# 2  POINT (34.783 32.053)
# 3  POINT (34.769 32.063)
# 4  POINT (34.766 32.069)
#
# [5 rows x 161 columns]

# %%
i_m_h_ta_gdf[(i_m_h_ta_gdf.involve_vehicle_type.isin(micro_m))].head()
# Out:
#      accident_id  provider_and_id  provider_code  file_type_police  \
# 23    2013001368      32013001368              3                 3
# 87    2013001742      32013001742              3                 3
# 117   2013001350      12013001350              1                 1
# 246   2013007702      32013007702              3                 3
# 259   2013009458      12013009458              1                 1
#
#      involved_type involved_type_hebrew  license_acquiring_date  age_group  \
# 23               2             נהג נפגע                       0          6
# 87               2             נהג נפגע                       0          7
# 117              2             נהג נפגע                       0          5
# 246              2             נהג נפגע                       0          9
# 259              2             נהג נפגע                       0         15
#
#     age_group_hebrew  sex  ... vehicle_status_hebrew  vehicle_attribution  \
# 23             25-29    1  ...                  None                  1.0
# 87             30-34    2  ...                  None                  1.0
# 117            20-24    1  ...                  None                  1.0
# 246            40-44    1  ...                  None                  1.0
# 259            70-74    1  ...                  None                  1.0
#
#     vehicle_attribution_hebrew  seats total_weight  total_weight_hebrew  \
# 23                      ישראלי   99.0          0.0              לא ידוע
# 87                      ישראלי   99.0          0.0              לא ידוע
# 117                     ישראלי   99.0          0.0              לא ידוע
# 246                     ישראלי   99.0          0.0              לא ידוע
# 259                     ישראלי   99.0          0.0              לא ידוע
#
#     vehicle_damage  vehicle_damage_hebrew        accident_date  \
# 23             4.0                אין נזק  2013-07-27 01:00:00
# 87             4.0                אין נזק  2013-10-07 01:30:00
# 117            4.0                אין נזק  2013-08-25 01:00:00
# 246            4.0                אין נזק  2013-08-25 07:45:00
# 259            4.0                אין נזק  2013-06-10 08:00:00
#
#                   geometry
# 23   POINT (34.775 32.073)
# 87   POINT (34.772 32.062)
# 117  POINT (34.769 32.063)
# 246  POINT (34.782 32.088)
# 259  POINT (34.784 32.066)
#
# [5 rows x 161 columns]

# %%
i_m_h_ta_gdf[(i_m_h_ta_gdf.involve_vehicle_type.isin(micro_m))].to_parquet('./csv_tables/i_m_h_ta_mm_gdf.parquet')
