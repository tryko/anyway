# %%
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
import pandas as pd
import numpy as np
from IPython.display import Image, display

# %% [markdown]
# # Load and convert TA geo data
# ### TA accidents
# * Convert TA longitude and latitude to shapely data point
# * Convert point to epsg 32636
# ### TA Bicycle Path
# * Load and fix BP street names
# ### TA Streets
# *

# %% [markdown]
# ### TA accidents
# * Convert TA longitude and latitude to shapely data point
# * Convert point to epsg 32636

# %%
i_m_h_ta = pd.read_csv('./csv_tables/i_m_h_ta.csv')
i_m_h_ta
# Out:
# C:\Users\itay8\AppData\Local\Temp\ipykernel_19292\1775048707.py:1: DtypeWarning: Columns (44,151) have mixed types. Specify dtype option on import or set low_memory=False.
#   i_m_h_ta = pd.read_csv('./csv_tables/i_m_h_ta.csv')
#         accident_id  provider_and_id  provider_code  file_type_police  \
# 0        2013001076      32013001076              3                 3
# 1        2013001885      32013001885              3                 3
# 2        2013000001      12013000001              1                 1
# 3        2013002115      32013002115              3                 3
# 4        2013000005      12013000005              1                 1
# ...             ...              ...            ...               ...
# 107196   2023098840      32023098840              3                 3
# 107197   2023098343      12023098343              1                 1
# 107198   2023097423      32023097423              3                 3
# 107199   2023099879      12023099879              1                 1
# 107200   2023099292      32023099292              3                 3
#
#         involved_type involved_type_hebrew  license_acquiring_date  age_group  \
# 0                   1                  נהג                    2010         13
# 1                   2             נהג נפגע                    2003          7
# 2                   3                 נפגע                       0         12
# 3                   1                  נהג                       0         99
# 4                   1                  נהג                    2006         10
# ...               ...                  ...                     ...        ...
# 107196              3                 נפגע                       0          7
# 107197              1                  נהג                    2015          6
# 107198              1                  נהג                    2019          5
# 107199              3                 נפגע                       0         15
# 107200              2             נהג נפגע                    2022          4
#
#        age_group_hebrew  sex  ... vehicle_status  vehicle_status_hebrew  \
# 0                 60-64    1  ...            0.0                    NaN
# 1                 30-34    1  ...            0.0                    NaN
# 2                 55-59    1  ...            NaN                    NaN
# 3               לא ידוע    0  ...            0.0                    NaN
# 4                 45-49    1  ...            0.0                    NaN
# ...                 ...  ...  ...            ...                    ...
# 107196            30-34    2  ...            NaN                    NaN
# 107197            25-29    2  ...            0.0                    NaN
# 107198            20-24    1  ...            0.0                    NaN
# 107199            70-74    2  ...            NaN                    NaN
# 107200            15-19    1  ...            0.0                    NaN
#
#        vehicle_attribution  vehicle_attribution_hebrew seats  total_weight  \
# 0                      1.0                      ישראלי   3.0           1.0
# 1                      1.0                      ישראלי   1.0           NaN
# 2                      NaN                         NaN   NaN           NaN
# 3                      1.0                      ישראלי  99.0           0.0
# 4                      1.0                      ישראלי  35.0          11.0
# ...                    ...                         ...   ...           ...
# 107196                 NaN                         NaN   NaN           NaN
# 107197                 1.0                      ישראלי  99.0           1.0
# 107198                 1.0                      ישראלי  99.0           0.0
# 107199                 NaN                         NaN   NaN           NaN
# 107200                 1.0                      ישראלי   1.0           1.0
#
#        total_weight_hebrew  vehicle_damage vehicle_damage_hebrew  \
# 0                   עד 1.9             4.0               אין נזק
# 1                      NaN             4.0               אין נזק
# 2                      NaN             NaN                   NaN
# 3                  לא ידוע             1.0                    קל
# 4                16.0-19.0             4.0               אין נזק
# ...                    ...             ...                   ...
# 107196                 NaN             NaN                   NaN
# 107197              עד 1.9             4.0               אין נזק
# 107198             לא ידוע             4.0               אין נזק
# 107199                 NaN             NaN                   NaN
# 107200              עד 1.9             4.0               אין נזק
#
#               accident_date
# 0       2013-09-07 00:30:00
# 1       2013-11-02 01:45:00
# 2       2013-01-02 00:00:00
# 3       2013-04-16 02:15:00
# 4       2013-01-09 00:00:00
# ...                     ...
# 107196  2023-06-13 20:45:00
# 107197  2023-02-07 15:45:00
# 107198  2023-06-20 09:00:00
# 107199  2023-04-20 13:15:00
# 107200  2023-02-23 17:00:00
#
# [107201 rows x 160 columns]

# %%
filtered_df = i_m_h_ta.dropna(subset=['longitude', 'latitude'])

longitude = filtered_df.longitude 
latitude = filtered_df.latitude

# Convert DataFrame to GeoDataFrame
i_m_h_ta = gpd.GeoDataFrame(
    filtered_df,
    geometry=[Point(xy) for xy in zip(longitude, latitude)]
)


i_m_h_ta_gdf = i_m_h_ta.set_crs(epsg=32636)
i_m_h_ta_gdf.crs
# Out:
# <Projected CRS: EPSG:32636>
# Name: WGS 84 / UTM zone 36N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 30°E and 36°E, northern hemisphere between equator and 84°N, onshore and offshore. Belarus. Cyprus. Egypt. Ethiopia. Finland. Israel. Jordan. Kenya. Lebanon. Moldova. Norway. Russian Federation. Saudi Arabia. Sudan. Syria. Türkiye (Turkey). Uganda. Ukraine.
# - bounds: (30.0, 0.0, 36.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 36N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
i_m_h_ta_gdf.to_parquet('./csv_tables/i_m_h_ta_gdf.parquet')

# %% [markdown]
# ## TA Bicycle Path
# * Load and fix BP street names

# %%
# Load the BP
bicycle_paths = gpd.read_file("./csv_tables/tel_avlv_bycicle_UTM/Bicycle Routes.shp")
bicycle_paths.columns = ['oid_shvil', 'msorech', 'dateimport', 'width', 'direction', 'create_year',
                         'shemmikta', 'miflas', 'create_date', 'geometry']
bicycle_paths.create_year = bicycle_paths.create_year.fillna(-1).astype(int)
bicycle_paths
# changing col names to fit other dataframes 
bicycle_paths.oid_shvil = pd.to_numeric(bicycle_paths.oid_shvil, downcast='integer')
display(bicycle_paths.crs)
bicycle_paths
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
#      oid_shvil  msorech           dateimport  width direction  create_year  \
# 0            1    95.10  11/02/2024 00:31:49    2.5   דו סטרי         2012
# 1            2   201.14  11/02/2024 00:31:49    2.5   דו סטרי         2013
# 2            3   696.31  11/02/2024 00:31:49    2.1   דו סטרי         2004
# 3            4   659.20  11/02/2024 00:31:49    2.5   דו סטרי         2018
# 4            5   362.67  11/02/2024 00:31:49    2.0   דו סטרי         2018
# ..         ...      ...                  ...    ...       ...          ...
# 853        452   172.22  11/02/2024 00:31:49    1.5      None         2016
# 854        453   268.59  11/02/2024 00:31:49    2.5   דו סטרי         2023
# 855        454    24.93  11/02/2024 00:31:49    NaN      None           -1
# 856        455   155.53  11/02/2024 00:31:49    2.5   דו סטרי         2022
# 857        456   237.22  11/02/2024 00:31:49    NaN      None           -1
#
#                                      shemmikta miflas create_date  \
# 0                         נמיר מיוניצ'מן דרומה   None        None
# 1                   פרופס מנמיר עד קדושי השואה   None        None
# 2     יאיר רוזנבלום מאורי צבי גרינברג עד פרופס   None        None
# 3                     קק"ל מנמיר עד חיים לבנון  מדרכה        None
# 4    רקנאטי בגינה מקרן קיימת לישראל עד אחימאיר   None        None
# ..                                         ...    ...         ...
# 853            הגדוד העברי מללוינסקי עד צ'לנוב   None        None
# 854                   נמיר מרוקח עד חיים לבנון   כביש        None
# 855                                       None   None        None
# 856                            גשר רדינג ווקוף   כביש        None
# 857                                       None   None        None
#
#                                               geometry
# 0    LINESTRING (34.80054 32.14000, 34.80089 32.140...
# 1    LINESTRING (34.79394 32.12300, 34.79327 32.123...
# 2    LINESTRING (34.79394 32.12300, 34.79413 32.123...
# 3    LINESTRING (34.79522 32.12243, 34.79581 32.122...
# 4    LINESTRING (34.80148 32.12168, 34.80166 32.122...
# ..                                                 ...
# 853  LINESTRING (34.77990 32.05691, 34.77964 32.057...
# 854  LINESTRING (34.79361 32.10025, 34.79356 32.100...
# 855  LINESTRING (34.77309 32.08740, 34.77284 32.08746)
# 856  LINESTRING (34.77632 32.10170, 34.77628 32.101...
# 857  LINESTRING (34.77364 32.09262, 34.77451 32.092...
#
# [858 rows x 10 columns]

# %% [markdown]
# Fix street names

# %%
clean_st_names = []
bp_street_names = pd.read_csv('./csv_tables/bp_street_name_only.csv', index_col=0)
for index, row in bp_street_names.iterrows():
    if isinstance(row['street_name'], float):
        clean_st_names.append('')
    else:
        st_name = row['street_name'].split("מ-")
        clean_st_names.append(st_name[0].strip())


clean_st_names
# Out:
# ['נמיר',
#  'פרופס',
#  'יאיר רוזנבלום',
#  'קרן קיימת לישראל',
#  'רקנאטי בגינה',
#  '2426',
#  'שי עגנון',
#  'איינשטיין',
#  'איינשטיין',
#  'שי עגנון',
#  'משעול 2364',
#  'בני אפריים',
#  'אהרון בקר',
#  'אהרון בקר',
#  'בני אפרים',
#  'בני אפרים',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון שביל 7.10',
#  'פארק הירקון שביל 7.10',
#  'פארק הירקון שביל 7.10',
#  'פארק הירקון שביל 7.10',
#  'פארק הירקון שביל 7.10',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'רוקח',
#  'רוקח',
#  'רוקח',
#  'רוקח',
#  'רוקח',
#  'רוקח',
#  'רוקח',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'נמל ת"א',
#  'חבקוק',
#  '2397',
#  'הרברט סמואל',
#  'נורדאו',
#  'נורדאו',
#  'נורדאו',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'פנקס',
#  'נמיר',
#  'נמיר',
#  'ויצמן',
#  'דוד המלך',
#  'דוד המלך',
#  'דוד המלך',
#  'בלוך',
#  'בלוך',
#  'שד בן גוריון',
#  'שד בן גוריון',
#  'שד בן גוריון',
#  'שד חן',
#  'מלכי ישראל',
#  'קפלן',
#  'מרמורק מזרח',
#  'מרמורק מזרח',
#  'קבוץ גלויות',
#  'קבוץ גלויות',
#  'קבוץ גלויות',
#  'קבוץ גלויות',
#  'אזר',
#  '3383',
#  'הלר חיים',
#  'הלר חיים',
#  '3956',
#  'חבר הלאומים',
#  'הטייסים',
#  'הטייסים',
#  'הטייסים',
#  'הטייסים',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'גבעתי',
#  'שד החי"ל',
#  'שד החי"ל',
#  'שד החי"ל',
#  'יד לבנים',
#  'יד לבנים',
#  'יצחק שדה',
#  'יצחק שדה',
#  'יצחק שדה',
#  'יצחק שדה',
#  'בת ציון',
#  'ברנדיס',
#  "לאונרדו דה וינצ'י",
#  'יונה הנביא',
#  'שיינקין',
#  'שיינקין',
#  'משעול',
#  'נמיר',
#  'נמיר',
#  "ג'ורג' וויז",
#  'יריד המזרח',
#  'משעול שירה',
#  'אינשטיין',
#  'רוקח',
#  'גשר למרכז רבין',
#  'יגור',
#  "צ'רצ'יל",
#  '1247',
#  "לאונרדו דה וינצ'י",
#  'הגבורה',
#  'שפע טל דרך גבעת התחמושת',
#  'קלוזנר',
#  'קלוזנר',
#  'שטרייכמן',
#  'יצחק אלחנן',
#  'יצחק אלחנן',
#  'החשמונאים',
#  'קרליבך',
#  'עליית הנוער',
#  "צ'לנוב",
#  "קלצ'קין",
#  'קוממיות',
#  'יהודה הנשיא',
#  'קוממיות',
#  'פרסיץ שושנה',
#  'רמז דוד',
#  'רמז דוד',
#  'מטלון',
#  'נירים',
#  'הרכבת',
#  'הרכבת',
#  'בצלאל יפה',
#  'חכמי  לובלין',
#  'שד הבעש"ט',
#  '3178',
#  'גן דוידוב',
#  'גן דוידוב',
#  'דרך יגאל ידין',
#  'דרך יגאל ידין',
#  'רח 3922',
#  'אייזיק חריף',
#  'שקד',
#  'שזר',
#  'לוי אשכול',
#  'לוי אשכול',
#  'לוי אשכול',
#  'לוי אשכול',
#  'יריד המזרח',
#  'בני דן',
#  'אחימאיר אבא',
#  'רקנאטי',
#  "ג'ורג' וויז",
#  'אופנהיימה',
#  'מסוף סבידור',
#  'שאול המלך',
#  "ז'בוטינסקי",
#  "ז'בוטינסקי",
#  "ז'בוטינסקי",
#  "ז'בוטינסקי",
#  "ז'בוטיסנקי",
#  "ז'בוטיסנקי",
#  'הרכבת',
#  'לה גווארדיה',
#  'פארק החורשות',
#  'פארק החורשות',
#  'פארק החורשות',
#  'פארק החורשות',
#  'פארק החורשות',
#  'פארק החורשות',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'שביל חיבור בין ארליך לשמואל ירחינאי',
#  'בת ים',
#  'מחרוזת',
#  'מחרוזת',
#  'מחרוזת',
#  'מחרוזת',
#  '3920',
#  'הטייסים',
#  'דרך דיין משה',
#  'ויצמן',
#  'הרב ניסים',
#  'סטפן צוויג',
#  'דבורה הנביאה',
#  'דבורה הנביאה',
#  'דבורה הנביאה',
#  'דבורה הנביאה',
#  'דבורה הנביאה',
#  'אליפלט',
#  'שנקר אריה',
#  'תובל',
#  'בשביס זינגר',
#  'משה סנה',
#  'אונטרמן',
#  'קרייתי',
#  'מח"ל',
#  'ברזילי',
#  'עזה',
#  'גרוסמן',
#  'גרינבויים',
#  'סהרון',
#  'יהודה הימית',
#  'יהודה הימית',
#  'יהודה הימית',
#  'יהודה הימית',
#  'יהודה הימית',
#  'יהודה הימית',
#  'יהודה הימית',
#  'בן צבי',
#  'קויפמן',
#  'קויפמן',
#  'קויפמן',
#  'קויפמן',
#  'הולצברג שמחה',
#  'ויצמן',
#  'ויצמן',
#  'בלוך',
#  'בלוך',
#  'בלוך',
#  'משמר הירדן',
#  'משמר הירדן',
#  'משמר הירדן',
#  'שארית ישראל',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'רוקח',
#  'כ"ה ו- 4881 חיבור בין אונטרמן למחל',
#  'הרב אשי + חיבור לקרן קיימת לישראל',
#  "יוניצ'מן",
#  '2379',
#  'ברלין אליהו',
#  'אבן גבירול',
#  'רוטלוי דוד',
#  'בריכת גורדון',
#  'שד בן ציון',
#  'שד מלכי ישראל',
#  'מח"ל',
#  'שד ההשכלה',
#  'קרן קיימת לישראל',
#  'חנה רובינא',
#  '1116',
#  'חנה זמר',
#  'טיילת יפו',
#  'הרב גורן',
#  'הרב גורן',
#  'הרב גורן',
#  'דוד אבידן',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'אלון יגאל',
#  'שד בן גוריון',
#  'שדרות ירושלים',
#  'הרב גורן',
#  'הרב גורן',
#  'מארק שאגאל',
#  'רפידים',
#  'רפידים',
#  'שביל הטיילת הצפונית',
#  'מח"ל',
#  'מח"ל',
#  'מח"ל',
#  'מח"ל',
#  'אלון יגאל',
#  'הרב ניסים',
#  'אופנהיימר',
#  'טאגור',
#  'נמיר',
#  'נמיר',
#  'מקס ברוד',
#  'וינגייט',
#  'וינגייט',
#  'חיבור וינגייט ללה גארדיה',
#  'גשר יהודית',
#  'גשר יהודית',
#  'גשר יהודית',
#  'יד המעביר',
#  'הדר יוסף',
#  'הדר יוסף',
#  'הדר יוסף',
#  'גינת הדר יוסף',
#  'גינת הדר יוסף',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'היינריך היינה',
#  'צומת היינריך היינה בן צבי',
#  'צומת היינריך היינה בן צבי',
#  'צומת היינריך היינה בן צבי',
#  'צומת היינריך היינה בן צבי',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'שלבים',
#  'צומת שלבים התחיה',
#  'צומת שלבים התחיה',
#  'צומת שלבים שארית ישראל',
#  'פינסקר',
#  'סלומון',
#  'היינריך היינה',
#  'צומת נס לגויים היינריך היינה',
#  'צומת נס לגויים היינריך היינה',
#  'צומת נס לגויים היינריך היינה',
#  'צומת נס לגויים היינריך היינה',
#  'צומת נס לגויים היינריך היינה',
#  'היינריך היינה',
#  'לוין קיפניס',
#  'קרמינצקי',
#  'גרוסמן',
#  'דניאל הירקון עד הכרמל',
#  "נג'ארה",
#  'הארבעה',
#  'הלל הזקן',
#  'וילנסקי משה',
#  'מנחם בגין',
#  'שלונסקי בני',
#  'שלונסקי בני',
#  'שלונסקי בני',
#  'בירנית',
#  'בירנית',
#  'בירנית',
#  'ככר דיזנגוף',
#  'חיבור בין נמיר לגילוץ',
#  'הוברמן',
#  'מעבר חציה ויצמן דוד המלך',
#  'אמיר גלבוע',
#  'אמיר גלבוע',
#  'מעבר חציה אבן גבירול יהודה המכבי',
#  '1284',
#  '1284',
#  'שביל מאחורי רחוב הברזל',
#  'דניאל',
#  'דיזנגוף',
#  'ככר הא באייר שביל זמני',
#  'יצחק אלחנן',
#  'יצחק אלחנן',
#  'יצחק אלחנן',
#  'יצחק אלחנן',
#  'אבנר מזרח מרכז הספורט',
#  'נח מוזס',
#  'בן יהודה',
#  'בן יהודה',
#  'בן יהודה',
#  'פארק המסילה 3817',
#  'היינריך היינה',
#  'נח מוזס שביל דרומי',
#  'ארנס בלוך',
#  'בנטוב',
#  'בנטוב',
#  'בנטוב',
#  'יד המעביר',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'פארק דרום',
#  'בירנית',
#  'בירנית',
#  'בירנית',
#  'בירנית',
#  'בירנית',
#  'בירנית',
#  'פארק שגאל לים',
#  'פארק שגאל לים',
#  'ככר אתרים והירידה לבן גוריון',
#  'מגדל שרשן',
#  'שלום אש',
#  'שלום אש',
#  'שלום אש',
#  'בן יהודה',
#  'בן יהודה',
#  'בן יהודה',
#  '2381',
#  'סשא ארגוב',
#  'סשא ארגוב',
#  'סשא ארגוב',
#  'סשא ארגוב',
#  'סשא ארגוב',
#  'סשא ארגוב',
#  'דיזנגוף',
#  'דיזנגוף',
#  'ארלוזורוב',
#  'פרי אליעזר',
#  'מעבר חציה אבן גבירול פנקס',
#  'מעבר חציה אבן גבירול בזל',
#  'גרינבויים',
#  'גרינבויים',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'דרך דיין משה -מגדה מזרחית',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'יהודה המכבי',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'בוגרשוב',
#  'מרמורק',
#  'נחלת בנימין',
#  'נחלת בנימין',
#  'נחלת בנימין',
#  'כ"ג יורדי הסירה (דיזנגוף הנמל)',
#  'כ"ג יורדי הסירה (דיזנגוף הנמל)',
#  'כ"ג יורדי הסירה (דיזנגוף הנמל)',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'יהודה הלוי',
#  'דיזנגוף',
#  'פנחס ספיר',
#  'פנחס ספיר',
#  'בן יהודה',
#  'בן יהודה',
#  'בן יהודה',
#  'בן יהודה',
#  'בן יהודה',
#  'לוין קיפניס',
#  'עיר שמש',
#  'אבוקה',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'פארק הירקון',
#  'אופני דן פארק הירקון',
#  'אופני דן פארק הירקון',
#  'אופני דן פארק הירקון',
#  'אופני דן פארק הירקון',
#  'אופני דן פארק הירקון',
#  'אופני דן פארק הירקון',
#  'מרים החשמונאית',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'אבן גבירול',
#  'מעבר חציה פנקס',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'ככר מחל אלנקווה',
#  'פלומר',
#  'פינסקר השלמה לבוגרשוב',
#  'פינסקר השלמה לבוגרשוב',
#  'רוקח',
#  'שלבים התחברות לשארית ישראל',
#  'נמל יפו',
#  'דיזנגוף',
#  'קרן קיימת',
#  'קרן קיימת',
#  'קוממיות',
#  'ירמיהו',
#  'ירמיהו',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'הרצל',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'דיזנגוף',
#  'צומת 1285 על פרשת דרכים',
#  'צומת 1285 על פרשת דרכים',
#  'צומת 1285 על פרשת דרכים',
#  'צומת 1285 על פרשת דרכים',
#  'צומת 1285 על פרשת דרכים',
#  'צומת 1285 על פרשת דרכים',
#  'צומת על פרשת דרכים ערבי נחל',
#  'צומת על פרשת דרכים ערבי נחל',
#  'צומת על פרשת דרכים ערבי נחל',
#  'צומת על פרשת דרכים ערבי נחל',
#  'צומת על פרשת דרכים ערבי נחל',
#  'סובה בעל פרשת דרכים',
#  'על פרשת דרכים',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מקטע מתוך על פרשת דרכים',
#  'על פרשת דרכים',
#  'אבן גבירול',
#  'אבן גבירול',
#  'חיבור אוסישקין לפארק',
#  'ספיר פנחס שרון 10',
#  'ספיר פנחס שרון 10',
#  'ספיר פנחס שרון 10',
#  'יעקב דורי שרון 10',
#  'שביל שרון פארק גני יהושע 9.1',
#  'פארק הירקון',
#  'מעבר חציה אבן גיברול זבוטינסקי והשלמה של זבוטינסקי',
#  'מעבר חציה אבן גיברול זבוטינסקי והשלמה של זבוטינסקי',
#  'מעבר חציה אבן גיברול זבוטינסקי והשלמה של זבוטינסקי',
#  'אבן גיברול',
#  'אבן גיברול',
#  'אבן גיברול',
#  'הנחושת',
#  'דיזנגוף',
#  'דרך דיין משה',
#  'דרך דיין משה גדה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'צומת דרך דיין משה לה גוארדיה',
#  'דרך דיין משה גדה מזרחית השלמת קטעים',
#  'פארק המסילה המשך עד נחלת בנימין',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'ארלוזורוב',
#  'דרך דיין משה גדה מזרחית',
#  'רוקח',
#  'אלון יגאל',
#  '3960',
#  '3960',
#  'אלון יגאל',
#  'אלון יגאל',
#  'חיל השריון',
#  'חיל השריון',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'בן צבי',
#  'רח 2040',
#  'דיזנגוף',
#  'נחל הבשור',
#  'שדרות ירושלים',
#  'קויפמן מאילת לחלץ',
#  '3965 הבלונים',
#  '3965 הבלונים',
#  'ירימיהו מזרח חיבור לפארק',
#  'רדינג',
#  'רדינג',
#  'רדינג',
#  'רדינג',
#  'שאול המלך',
#  'שאול המלך',
#  'יצחק שדה',
#  'לינקולן',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'הרכבת',
#  'הרכבת',
#  'ישראל גורי',
#  'היינריך היינה מאחורי הקיר האקוסטי שביל 2.1',
#  'מנשה בן ישראל',
#  'מנשה בן ישראל',
#  'צומת שלמה מסילת ישרים',
#  'הוברמן מהחניון עד מרמורק',
#  'הורדצקי',
#  'צמתים בלוי אשכול',
#  'צמתים בלוי אשכול',
#  'היינריך היינה',
#  'פארק הירקון',
#  'הרב גורן',
#  'הרב גורן',
#  'הרב גורן',
#  'מנחם בגין צד מערבי',
#  'מנחם בגין צד מערבי',
#  'מנחם בגין צד מערבי',
#  'בן יהודה',
#  '1310',
#  'צומת יצחק שדה לינקולן גשר מעריב',
#  'צומת יצחק שדה לינקולן גשר מעריב',
#  'צומת יצחק שדה לינקולן גשר מעריב',
#  'בנטוב המשך',
#  'משה סנה',
#  'פנחס רוזן',
#  'שביל המימדיון',
#  'צומת לוי אשכול מארק שאגאל',
#  'הרצל',
#  'יהודה הלוי',
#  'צומת בן צבי הרצל',
#  'דבורה הנביאה',
#  'קפריסין',
#  'קפריסין',
#  'ברודצקי',
#  'אורי צבי גרינברג',
#  'ויצמן',
#  'ויצמן',
#  'ויצמן',
#  'בן יהודה',
#  'בן יהודה',
#  'צומת יהודה המכבי ויצמן',
#  'צומת יהודה המכבי ויצמן',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'ישראל טל',
#  'שד יהודית',
#  'שד יהודית',
#  'שד יהודית',
#  '1364',
#  'מידטאון',
#  'מידטאון',
#  'חיבור רחוב שיטרית למימדיון',
#  'פרייגרזון צבי',
#  'פרייגרזון צבי',
#  'דרך דיין משה',
#  'דרך דיין משה',
#  'דרך דיין משה גדה מזרחית',
#  'דרך דיין משה גדה מזרחית',
#  'דרך דיין משה גדה מזרחית',
#  'מח"ל',
#  '2040',
#  '2040',
#  '2040',
#  'ארצי ישראל',
#  'ארצי יצתק',
#  'דרך השלום',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'שדרות ירושלים',
#  'צומת רמז דוד פנקס ברנדיס',
#  'צומת רמז דוד פנקס ברנדיס',
#  'צומת רמז דוד פנקס ברנדיס',
#  'צומת רמז דוד פנקס ברנדיס',
#  'צומת רמז דוד פנקס ברנדיס',
#  'צומת רמז דוד פנקס ברנדיס',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'מנחם בגין',
#  'שאול המלך',
#  'שאול המלך',
#  'שאול המלך',
#  'שאול המלך',
#  'שאול המלך',
#  'בן יהודה',
#  'רוקח',
#  'זלצמן פנינה',
#  'זלצמן פנינה',
#  'דרך בגין',
#  'תל גיבורים',
#  'צומת הלסינקי זבוטינסקי',
#  'צומת הלסינקי זבוטינסקי',
#  'צומת הלסינקי זבוטינסקי',
#  'צומת הלסינקי זבוטינסקי',
#  'צומת הלסינקי זבוטינסקי',
#  'שיטרית',
#  'משה',
#  'היכל תלמוד',
#  'מנחם בגין',
#  'אלנבי',
#  'גשר יצחק שדה',
#  'נחום גולדמן',
#  'מנחם בגין',
#  'גבעת התחמושת',
#  'גבעת התחמושת',
#  'גבעת התחמושת',
#  'גבעת התחמושת',
#  'גבעת התחמושת',
#  'גבעת התחמושת',
#  'דרך השרות המזרחית',
#  'טיילת איילון',
#  'לוי אשכול',
#  'לוי אשכול',
#  'פנחס רוזן',
#  'פנחס רוזן',
#  'פנחס רוזן',
#  'פנחס רוזן',
#  'גן מאיר',
#  'רוטשילד',
#  'רוטשילד',
#  'רוטשילד',
#  'ראול וולנברג',
#  'בני אפרים',
#  'פארק הירקון',
#  'גיתית',
#  'ישראל גורי',
#  'ישראל גורי',
#  'ישראל גורי',
#  'ישראל גורי',
#  'ישראל גורי',
#  'ישראל גורי',
#  'ישראל גורי',
#  'פארק הירקון',
#  'אבן גבירול  גדה מערבית',
#  'אבן גבירול  גדה מערבית',
#  'פרופס',
#  'פרופס',
#  'פרופס',
#  'פרופס',
#  '2425',
#  '2425',
#  '2425',
#  '2425',
#  '2425',
#  '2425 מערב',
#  '2425 מערב',
#  'רח 2040',
#  'איינשטיין',
#  'איינשטיין',
#  'איינשטיין',
#  'טיילת הפארק החופי',
#  '',
#  '',
#  '',
#  '',
#  'חזית מתחם וויקס',
#  'ראול ולנברג',
#  'גשר איינשטיין',
#  'אינשטיין',
#  'נמיר',
#  'שי עגנון',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'אבן גבירול החדש/2040',
#  '',
#  'שניצר',
#  '',
#  'קדושי השואה',
#  '',
#  '',
#  '',
#  '',
#  'אבן גבירול החדש/2040',
#  '2434',
#  'רחוב 2434 סביב תיכונט',
#  'רחוב 2434 סביב תיכונט',
#  'הגדוד העברי',
#  'נמיר',
#  '',
#  'גשר רדינג ווקוף',
#  '']

# %%
bicycle_paths['street_name'] = clean_st_names
bicycle_paths
# Out:
#      oid_shvil  msorech           dateimport  width direction  create_year  \
# 0            1    95.10  11/02/2024 00:31:49    2.5   דו סטרי         2012
# 1            2   201.14  11/02/2024 00:31:49    2.5   דו סטרי         2013
# 2            3   696.31  11/02/2024 00:31:49    2.1   דו סטרי         2004
# 3            4   659.20  11/02/2024 00:31:49    2.5   דו סטרי         2018
# 4            5   362.67  11/02/2024 00:31:49    2.0   דו סטרי         2018
# ..         ...      ...                  ...    ...       ...          ...
# 853        452   172.22  11/02/2024 00:31:49    1.5      None         2016
# 854        453   268.59  11/02/2024 00:31:49    2.5   דו סטרי         2023
# 855        454    24.93  11/02/2024 00:31:49    NaN      None           -1
# 856        455   155.53  11/02/2024 00:31:49    2.5   דו סטרי         2022
# 857        456   237.22  11/02/2024 00:31:49    NaN      None           -1
#
#                                      shemmikta miflas create_date  \
# 0                         נמיר מיוניצ'מן דרומה   None        None
# 1                   פרופס מנמיר עד קדושי השואה   None        None
# 2     יאיר רוזנבלום מאורי צבי גרינברג עד פרופס   None        None
# 3                     קק"ל מנמיר עד חיים לבנון  מדרכה        None
# 4    רקנאטי בגינה מקרן קיימת לישראל עד אחימאיר   None        None
# ..                                         ...    ...         ...
# 853            הגדוד העברי מללוינסקי עד צ'לנוב   None        None
# 854                   נמיר מרוקח עד חיים לבנון   כביש        None
# 855                                       None   None        None
# 856                            גשר רדינג ווקוף   כביש        None
# 857                                       None   None        None
#
#                                               geometry       street_name
# 0    LINESTRING (34.80054 32.14000, 34.80089 32.140...              נמיר
# 1    LINESTRING (34.79394 32.12300, 34.79327 32.123...             פרופס
# 2    LINESTRING (34.79394 32.12300, 34.79413 32.123...     יאיר רוזנבלום
# 3    LINESTRING (34.79522 32.12243, 34.79581 32.122...  קרן קיימת לישראל
# 4    LINESTRING (34.80148 32.12168, 34.80166 32.122...      רקנאטי בגינה
# ..                                                 ...               ...
# 853  LINESTRING (34.77990 32.05691, 34.77964 32.057...       הגדוד העברי
# 854  LINESTRING (34.79361 32.10025, 34.79356 32.100...              נמיר
# 855  LINESTRING (34.77309 32.08740, 34.77284 32.08746)
# 856  LINESTRING (34.77632 32.10170, 34.77628 32.101...   גשר רדינג ווקוף
# 857  LINESTRING (34.77364 32.09262, 34.77451 32.092...
#
# [858 rows x 11 columns]

# %%
bicycle_paths.to_parquet('./csv_tables/bicycle_paths_corrected.parquet')
