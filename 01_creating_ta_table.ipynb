# %%
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
import pandas as pd
import numpy as np
from IPython.display import Image, display

# %%
i_m_h = pd.read_csv('./csv_tables/involved_markers_hebrew_corrected.csv')
# Out:
# C:\Users\itay8\AppData\Local\Temp\ipykernel_2940\3865934326.py:1: DtypeWarning: Columns (151) have mixed types. Specify dtype option on import or set low_memory=False.
#   i_m_h = pd.read_csv('./csv_tables/involved_markers_hebrew_corrected.csv')

# %%
i_m_h[i_m_h.accident_yishuv_symbol == 5000].copy().to_csv('./csv_tables/i_m_h_ta.csv', index=False)

# %%
i_m_h[i_m_h.accident_yishuv_symbol == 5000]
# Out:
#          accident_id  provider_and_id  provider_code  file_type_police  \
# 4         2013001076      32013001076              3                 3
# 17        2013001885      32013001885              3                 3
# 18        2013000001      12013000001              1                 1
# 24        2013002115      32013002115              3                 3
# 26        2013000005      12013000005              1                 1
# ...              ...              ...            ...               ...
# 1427526   2023098840      32023098840              3                 3
# 1427540   2023098343      12023098343              1                 1
# 1427546   2023097423      32023097423              3                 3
# 1427646   2023099879      12023099879              1                 1
# 1427658   2023099292      32023099292              3                 3
#
#          involved_type involved_type_hebrew  license_acquiring_date  \
# 4                    1                  נהג                    2010
# 17                   2             נהג נפגע                    2003
# 18                   3                 נפגע                       0
# 24                   1                  נהג                       0
# 26                   1                  נהג                    2006
# ...                ...                  ...                     ...
# 1427526              3                 נפגע                       0
# 1427540              1                  נהג                    2015
# 1427546              1                  נהג                    2019
# 1427646              3                 נפגע                       0
# 1427658              2             נהג נפגע                    2022
#
#          age_group age_group_hebrew  sex  ... vehicle_status  \
# 4               13            60-64    1  ...            0.0
# 17               7            30-34    1  ...            0.0
# 18              12            55-59    1  ...            NaN
# 24              99          לא ידוע    0  ...            0.0
# 26              10            45-49    1  ...            0.0
# ...            ...              ...  ...  ...            ...
# 1427526          7            30-34    2  ...            NaN
# 1427540          6            25-29    2  ...            0.0
# 1427546          5            20-24    1  ...            0.0
# 1427646         15            70-74    2  ...            NaN
# 1427658          4            15-19    1  ...            0.0
#
#          vehicle_status_hebrew vehicle_attribution  \
# 4                          NaN                 1.0
# 17                         NaN                 1.0
# 18                         NaN                 NaN
# 24                         NaN                 1.0
# 26                         NaN                 1.0
# ...                        ...                 ...
# 1427526                    NaN                 NaN
# 1427540                    NaN                 1.0
# 1427546                    NaN                 1.0
# 1427646                    NaN                 NaN
# 1427658                    NaN                 1.0
#
#          vehicle_attribution_hebrew seats  total_weight total_weight_hebrew  \
# 4                            ישראלי   3.0           1.0              עד 1.9
# 17                           ישראלי   1.0           NaN                 NaN
# 18                              NaN   NaN           NaN                 NaN
# 24                           ישראלי  99.0           0.0             לא ידוע
# 26                           ישראלי  35.0          11.0           16.0-19.0
# ...                             ...   ...           ...                 ...
# 1427526                         NaN   NaN           NaN                 NaN
# 1427540                      ישראלי  99.0           1.0              עד 1.9
# 1427546                      ישראלי  99.0           0.0             לא ידוע
# 1427646                         NaN   NaN           NaN                 NaN
# 1427658                      ישראלי   1.0           1.0              עד 1.9
#
#          vehicle_damage vehicle_damage_hebrew        accident_date
# 4                   4.0               אין נזק  2013-09-07 00:30:00
# 17                  4.0               אין נזק  2013-11-02 01:45:00
# 18                  NaN                   NaN  2013-01-02 00:00:00
# 24                  1.0                    קל  2013-04-16 02:15:00
# 26                  4.0               אין נזק  2013-01-09 00:00:00
# ...                 ...                   ...                  ...
# 1427526             NaN                   NaN  2023-06-13 20:45:00
# 1427540             4.0               אין נזק  2023-02-07 15:45:00
# 1427546             4.0               אין נזק  2023-06-20 09:00:00
# 1427646             NaN                   NaN  2023-04-20 13:15:00
# 1427658             4.0               אין נזק  2023-02-23 17:00:00
#
# [107201 rows x 160 columns]
